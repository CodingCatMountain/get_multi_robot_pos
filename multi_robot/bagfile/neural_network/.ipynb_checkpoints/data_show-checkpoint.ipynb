# %%
# import library
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../iiwa_sample.csv')
df.head()
df['link_pos_2'][0]
# Out:
#    Unnamed: 0                 time  iiwa_joint_1  iiwa_joint_2  iiwa_joint_3  \
# 0           0  1639136551979647857     -1.023703      1.574981     -1.380453
# 1           1  1639136552079621092     -0.660833      1.787243     -2.224873
# 2           2  1639136552179660552     -0.722299     -1.709814      2.502516
# 3           3  1639136552279538442      1.528708     -1.941011     -0.237681
# 4           4  1639136552379591108     -0.442515     -0.657734     -2.429591
#
#    iiwa_joint_4  iiwa_joint_5  iiwa_joint_6  iiwa_joint_7        link_pos_1  \
# 0      0.040636      0.986537     -0.482435     -3.004987  [0.0, 0.0, 0.15]
# 1     -1.123771     -1.012590      0.590475      2.086593  [0.0, 0.0, 0.15]
# 2      0.649813     -1.149104      0.054011      1.309701  [0.0, 0.0, 0.15]
# 3     -0.059155      0.305795     -0.442507     -2.550507  [0.0, 0.0, 0.15]
# 4      0.360640     -1.471721     -0.028956     -0.403869  [0.0, 0.0, 0.15]
#
#                         link_pos_2  \
# ...

# %%
df_noise = pd.read_csv('../iiwa_samples_with_noise.csv')
df_noise.head()
df_noise['link_pos_2'][0]
# Out:
# '[-0.09699981432535139, 0.15189635423931236, 0.15204656888350046]'
